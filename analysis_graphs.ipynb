# %%
# Dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
# Store filepath in a variable
csv_path = "Output/covid_week.csv"
# Read our Data file with the pandas library
covid_week_data = pd.read_csv(csv_path, encoding="utf-8")
covid_week_data.set_index("week", inplace=True)
covid_week_data
# Out:
#       report_date  status  gender  age_group  race_ethnicity  hospital  \
# week
# 1              21      21      21         21              21        21
# 2               9       9       9          9               9         9
# 3              29      29      29         29              29        29
# 4              33      33      33         33              33        33
# 5              70      70      70         70              70        70
# 6              55      55      55         55              55        55
# 7             100     100     100        100             100       100
# 8             211     211     211        211             211       211
# 9             719     719     719        719             719       719
# 10           2140    2140    2140       2140            2140      2140
# 11          12209   12209   12209      12209           12209     12209
# 12          38118   38118   38117      38116           38117     38118
# ...

# %%
covid_gender_df=covid_week_data[["Male", "Female", "Unknown Gender"]]
covid_gender_df.head()
# Out:
#       Male  Female  Unknown Gender
# week
# 1       10      11               0
# 2        5       4               0
# 3       19      10               0
# 4       15      18               0
# 5       34      36               0

# %%
covid_agegroup_df=covid_week_data[["0 - 9 Years","10 - 19 Years","20 - 29 Years","30 - 39 Years","40 - 49 Years",
                                 "50 - 59 Years","60 - 69 Years","70 - 79 Years","80+ Years","Unknown Age Group"]]
covid_agegroup_df.head()
# Out:
#       0 - 9 Years  10 - 19 Years  20 - 29 Years  30 - 39 Years  40 - 49 Years  \
# week
# 1               0              0              3              5              2
# 2               0              0              2              0              2
# 3               0              1              3              1              7
# 4               0              3              9              3              7
# 5               2              3              9              7              9
#
#       50 - 59 Years  60 - 69 Years  70 - 79 Years  80+ Years  \
# week
# 1                 5              3              3          0
# 2                 3              2              0          0
# 3                 8              6              2          1
# 4                 3              3              4          1
# 5                24             13              3          0
#
#       Unknown Age Group
# week
# 1                     0
# 2                     0
# 3                     0
# ...

# %%
covid_race_df=covid_week_data[["American Indian/Alaska Native","Asian","Black", "Hispanic/Latino",
                             "Multiple/Other", "Native Hawaiian/Other Pacific Islander", "White", "Unknown Race"]]
covid_race_df.head()
# Out:
#       American Indian/Alaska Native  Asian  Black  Hispanic/Latino  \
# week
# 1                                 0      1      1                0
# 2                                 0      0      0                0
# 3                                 0      3      4                1
# 4                                 1      5      4                1
# 5                                 0      8      8                2
#
#       Multiple/Other  Native Hawaiian/Other Pacific Islander  White  \
# week
# 1                  2                                       0     12
# 2                  0                                       0      4
# 3                  2                                       0     11
# 4                  2                                       0      9
# 5                  7                                       0     17
#
#       Unknown Race
# week
# 1                5
# 2                5
# 3                8
# 4               11
# 5               28

# %%
covid_death_df=covid_week_data[["Death-Yes", "Death-No", "Death-Unknown"]]
covid_death_df.head()
# Out:
#       Death-Yes  Death-No  Death-Unknown
# week
# 1             0        18              3
# 2             0         6              3
# 3             0        23              6
# 4             0        28              5
# 5             1        53             16

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_gender_sum=covid_gender_df.sum()
colors = ["blue","red","lightgray"]
covid_gender_sum.plot(kind="pie",colors=colors,autopct="%1.1f%%")

# Set a title for the chart
plt.title("Total U.S. COVID-19 Cases by Gender")
plt.axis("equal")
plt.show()
plt.savefig("Output/covid_gender_total.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_gender_df.plot(kind="line",figsize=(10,5))

# Set a title for the chart
plt.title("Weekly U.S. COVID-19 Cases by Gender")
plt.xticks(np.arange(0, 34, step=1))
plt.xlabel("Week")
plt.ylabel("# Cases")
plt.legend(loc="upper left")
plt.show()
plt.savefig("Output/covid_gender_time.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_agegroup_sum=covid_agegroup_df.sum()
covid_agegroup_sum.plot(kind="pie", autopct="%1.1f%%")

# Set a title for the chart
plt.title("Total U.S. COVID-19 Cases by Age Group")
plt.axis("equal")
plt.show()
plt.savefig("Output/covid_agegroup_total.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_agegroup_df.plot(kind="line", figsize=(10,5))

# Set a title for the chart
plt.title("Weekly U.S. COVID-19 Cases by Age Group")
plt.xticks(np.arange(0, 34, step=1))
plt.xlabel("Week")
plt.ylabel("# Cases")
plt.legend(loc="upper left")
plt.show()
plt.savefig("Output/covid_agegroup_time.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_race_sum=covid_race_df.sum()
covid_race_sum.plot(kind="pie", autopct="%1.1f%%")

# Set a title for the chart
plt.title("Total U.S. COVID-19 Cases by Race")
plt.axis("equal")
plt.show()
plt.savefig("Output/covid_race_total.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_race_df.plot(kind="line", figsize=(10,5))

# Set a title for the chart
plt.title("Weekly U.S. COVID-19 Cases by Race")
plt.xticks(np.arange(0, 34, step=1))
plt.xlabel("Week")
plt.ylabel("# Cases")
plt.legend(loc="upper left")
plt.show()
plt.savefig("Output/covid_race_time.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_death_sum=covid_death_df.sum()
covid_death_sum.plot(kind="pie", autopct="%1.1f%%")

# Set a title for the chart
plt.title("Total U.S. COVID-19 Deaths")
plt.show()
plt.savefig("Output/covid_death_total.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Use DataFrame.plot() in order to create a chart of the data
covid_death_df.plot(kind="line", figsize=(10,5))

# Set a title for the chart
plt.title("Weekly U.S. COVID-19 Deaths")
plt.xticks(np.arange(0, 34, step=1))
plt.xlabel("Week")
plt.ylabel("# Cases")
plt.legend(loc="upper left")
plt.show()
plt.savefig("Output/covid_death_time.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">
